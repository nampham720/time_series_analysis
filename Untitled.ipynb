# %%
# !zip -r mythesis.zip .
# Out:
#   adding: labels/ (stored 0%)
#   adding: labels/combined_windows.json (deflated 86%)
#   adding: labels/.ipynb_checkpoints/ (stored 0%)
#   adding: labels/.ipynb_checkpoints/combined_labels-checkpoint.json (deflated 80%)
#   adding: labels/.ipynb_checkpoints/combined_windows-checkpoint.json (deflated 86%)
#   adding: labels/combined_labels.json (deflated 80%)
#   adding: realKnownCause/ (stored 0%)
#   adding: realKnownCause/nyc_taxi.csv (deflated 80%)
#   adding: realKnownCause/rogue_agent_key_hold.csv (deflated 81%)
#   adding: realKnownCause/cpu_utilization_asg_misconfiguration.csv (deflated 83%)
#   adding: realKnownCause/rogue_agent_key_updown.csv (deflated 87%)
#   adding: realKnownCause/.ipynb_checkpoints/ (stored 0%)
#   adding: realKnownCause/.ipynb_checkpoints/machine_temperature_system_failure-checkpoint.csv (deflated 73%)
#   adding: realKnownCause/.ipynb_checkpoints/ambient_temperature_system_failure-checkpoint.csv (deflated 74%)
# ...
