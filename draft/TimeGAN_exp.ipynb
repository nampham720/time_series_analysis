# %%
import sys 
# !{sys.executable} -m pip install --user tensorflow -q
# !{sys.executable} -m pip install --user pyod -q
# !{sys.executable} -m pip install --user 'tensorflow[and-cuda]' -q 
# !{sys.executable} -m pip install --user optuna -q
# Out:
# WARNING: There was an error checking the latest version of pip.
# WARNING: There was an error checking the latest version of pip.
# WARNING: There was an error checking the latest version of pip.
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# # First step

# %%
import pandas as pd 
import psutil
import json
import matplotlib.pyplot as plt
import preprocess_functions as f 
import time 
import stats_helper as helper
import numpy as np
from scipy.stats import zscore
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.preprocessing import MinMaxScaler

PATH = 'realKnownCause/'
ERRORPATH = 'labels/combined_labels.json'
# load error data
with open(ERRORPATH, "r") as file:
    error_file = json.load(file)



file_names = f.get_all_files(PATH) # return all file paths
time_diffs, preprocessed_dfs = list(), list()
for file_name in file_names:
    time_diff, preprocessed_df = f.process_time_series(file_name, error_file) 
    time_diffs.append(time_diff)
    preprocessed_dfs.append(preprocessed_df)

def window_sizes_freq(time_diff):
    window_sizes = dict()
    window_sizes['daily'] = int(60*60*24 / time_diff)
    window_sizes['time_of_day'] = int(window_sizes['daily'] / 4)
    return window_sizes 

window_sizes = [window_sizes_freq(timediff) for timediff in time_diffs]

# %% [markdown]
# # Discriminative

# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from utils import extract_time 
from tensorflow.keras.callbacks import LambdaCallback

def train_test_divide(ori_data, generated_data, ori_time, generated_time):
    # Split original and generated data into training and testing sets
    train_x, test_x, train_t, test_t = train_test_split(ori_data, ori_time, test_size=0.2, random_state=42)
    train_x_hat, test_x_hat, train_t_hat, test_t_hat = train_test_split(generated_data, generated_time, test_size=0.2, random_state=42)
    
    return train_x, train_x_hat, test_x, test_x_hat, train_t, train_t_hat, test_t, test_t_hat

def t_discriminative_score_metrics(ori_data, generated_data, iterations=200, batch_size=128, patience=10):
    """Use post-hoc RNN to classify original data and synthetic data with optimizations."""
    
    ori_data = np.array(ori_data)
    generated_data = np.array(generated_data)

    # Get shape parameters
    no, seq_len, dim = ori_data.shape
    
    # Extract sequence lengths
    ori_time, ori_max_seq_len = extract_time(ori_data)
    generated_time, generated_max_seq_len = extract_time(generated_data)
    max_seq_len = max(ori_max_seq_len, generated_max_seq_len)
    
    # Network parameters
    hidden_dim = max(1, int(dim / 2))

    class Discriminator(tf.keras.Model):
        def __init__(self, hidden_dim):
            super(Discriminator, self).__init__()
            self.gru1 = tf.keras.layers.GRU(hidden_dim, return_sequences=True)
            self.gru2 = tf.keras.layers.GRU(hidden_dim, return_sequences=False)
            self.dense = tf.keras.layers.Dense(1, activation="sigmoid")

        def call(self, x):
            # Ensure input is 3D (batch_size, seq_len, feature_dim)
            if len(x.shape) == 2:  # If the input is 2D, reshape it to 3D
                x = tf.expand_dims(x, axis=0)  # Add batch dimension

            h = self.gru1(x)
            h = self.gru2(h)
            y_hat = self.dense(h)
            return y_hat

    # Instantiate the Discriminator
    discriminator = Discriminator(hidden_dim)
    optimizer = tf.keras.optimizers.Adam()
    loss_fn = tf.keras.losses.BinaryCrossentropy()

    # Train/test division for both original and generated data
    train_x, train_x_hat, test_x, test_x_hat, train_t, train_t_hat, test_t, test_t_hat = \
        train_test_divide(ori_data, generated_data, ori_time, generated_time)

    # Reshape the data to have 3 dimensions (batch_size, seq_len, features)
    train_x = train_x.reshape(-1, seq_len, 1)
    train_x_hat = train_x_hat.reshape(-1, seq_len, 1)
    test_x = test_x.reshape(-1, seq_len, 1)
    test_x_hat = test_x_hat.reshape(-1, seq_len, 1)

    # Create train_labels for the real and fake data
    train_labels_real = np.ones((train_x.shape[0], 1))
    train_labels_fake = np.zeros((train_x_hat.shape[0], 1))
    train_x_combined = np.concatenate((train_x, train_x_hat), axis=0)
    train_labels_combined = np.concatenate((train_labels_real, train_labels_fake), axis=0)

    # Shuffle data
    indices = np.arange(train_x_combined.shape[0])
    np.random.shuffle(indices)
    train_x_combined = train_x_combined[indices]
    train_labels_combined = train_labels_combined[indices]

    # Combine test data
    test_labels_real = np.ones((test_x.shape[0], 1))
    test_labels_fake = np.zeros((test_x_hat.shape[0], 1))
    test_x_combined = np.concatenate((test_x, test_x_hat), axis=0)
    test_labels_combined = np.concatenate((test_labels_real, test_labels_fake), axis=0)


    # Create TensorFlow datasets
    train_dataset = tf.data.Dataset.from_tensor_slices((train_x_combined, train_labels_combined)).batch(batch_size).repeat()

    # Early stopping setup
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=patience, restore_best_weights=True)
    
    # Compile the model
    discriminator.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

    # Train the model
    discriminator.fit(
        train_dataset,  # The training data
        epochs=iterations,  # Number of training epochs
        steps_per_epoch=len(train_x_combined) // batch_size,  # Define number of steps per epoch
        validation_data=(test_x_combined, test_labels_combined),  # Validation data
        callbacks=[early_stopping]  # Early stopping and custom epoch display
    )

    # Predict on test set
    y_pred_real = discriminator(test_x)
    y_pred_fake = discriminator(test_x_hat)

    y_pred_final = np.squeeze(np.concatenate((y_pred_real.numpy(), y_pred_fake.numpy()), axis=0))
    y_label_final = np.concatenate((np.ones(len(y_pred_real)), np.zeros(len(y_pred_fake))), axis=0)

    # Compute accuracy and discriminative score
    acc = accuracy_score(y_label_final, (y_pred_final > 0.5))
    discriminative_score = np.abs(0.5 - acc)

    return discriminative_score

# %% [markdown]
# # Predictive

# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import GRU, Dense, Dropout, Bidirectional
from tensorflow.keras.models import Sequential

def t_predictive_score_metrics(ori_data, generated_data, epochs=50, batch_size=128, n_splits=5):
    """Evaluate Post-hoc RNN one-step-ahead prediction with improvements.
    
    Args:
        - ori_data: Original time-series data
        - generated_data: Generated synthetic data
        - epochs: Number of training epochs
        - batch_size: Batch size for training
        - n_splits: Number of splits for cross-validation
        
    Returns:
        - predictive_score: Mean MAE of predictions on the original data
    """

    # Convert to NumPy arrays
    ori_data = np.asarray(ori_data, dtype=np.float32)
    generated_data = np.asarray(generated_data, dtype=np.float32)

    # Extract shape parameters
    no, seq_len, dim = ori_data.shape

    # Prepare the data for training and testing
    def prepare_data(data):
        """Prepares input-output pairs for the predictor."""
        X = np.array([d[:-1, -1:] for d in data])  # Keep only the last column (univariate time series)
        Y = np.array([d[1:, -1:] for d in data])  # The next time step prediction
        return X, Y

    # Prepare data for training
    X_ori, Y_ori = prepare_data(ori_data)
    X_gen, Y_gen = prepare_data(generated_data)

    # Define the model architecture
    def build_model(hidden_dim):
        """Build a simple RNN model."""
        model = Sequential()
        model.add(Bidirectional(GRU(hidden_dim, activation='tanh', return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.01))))
        model.add(Dropout(0.2))  # Dropout layer to reduce overfitting
        model.add(Dense(1, activation=None))  # Output layer with no activation
        model.compile(optimizer='adam', loss='mae')  # Mean Absolute Error Loss
        return model

    # Cross-validation setup
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    mae_scores = []

    # Cross-validation loop
    for train_index, val_index in kf.split(X_ori):
        X_train, X_val = X_ori[train_index], X_ori[val_index]
        Y_train, Y_val = Y_ori[train_index], Y_ori[val_index]
        
        # Create the model
        predictor = build_model(hidden_dim=max(1, int(dim / 2)))  # Hidden dimension is half the input dimension
        
        # Early stopping callback
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

        # Train the model
        predictor.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, 
                      validation_data=(X_val, Y_val), callbacks=[early_stopping], verbose=1)
        
        # Predict on the validation set (original data)
        pred_Y = predictor.predict(X_val)

        Y_val = Y_val.reshape(-1)  # Flatten to a 1D array
        pred_Y = pred_Y.reshape(-1)  # Flatten to a 1D array

        # Calculate MAE for this fold
        mae_score = mean_absolute_error(Y_val, pred_Y)
        mae_scores.append(mae_score)

    # Compute mean MAE across all folds
    predictive_score = np.mean(mae_scores)

    return predictive_score

# %% [markdown]
# # Implement

# %%
from timegan_v2_18 import timegan 
import optuna
import time
import numpy as np
import json

# %%
import json
import optuna
import numpy as np

def objective(trial, data_type):
    """Optimize hyperparameters using Optuna for both sequences (daily and time_of_day)."""
    
    # Sample hyperparameters
    hidden_dim = trial.suggest_int('hidden_dim', 10, 50, step=10)
    num_layers = trial.suggest_int('num_layer', 2, 3)
    batch_size = trial.suggest_int('batch_size', 32, 256, step=32)
    module = trial.suggest_categorical('module', ['gru', 'lstm'])
    
    combined_scores = []
    
    for window_size, preprocessed_df, file_name in zip(window_sizes, preprocessed_dfs, file_names):
        if file_name != 'realKnownCause/rogue_agent_key_hold.csv':
            continue
        print(f'Processing TimeGAN for {file_name} ({data_type} sequence)')
        name = file_name.split('/')[-1].split('.')[0]
        data = np.array(preprocessed_df['value']).reshape(-1, 1)
        
        # Prepare sequences based on the data_type (daily or time_of_day)
        if data_type == 'daily':
            time_series = [data[i:i + window_size['daily']] for i in range(len(data) - window_size['daily'])]
        else:  # 'time_of_day'
            time_series = [data[i:i + window_size['time_of_day']] for i in range(len(data) - window_size['time_of_day'])]
        
        ori_data = np.array(time_series)

        # Parameters for the model
        parameters = {
            "hidden_dim": hidden_dim,
            "num_layer": num_layers,
            "iterations": 10000,
            "batch_size": batch_size,
            "module": module
        }

        # Generate synthetic data for the sequence
        generated_data = timegan(ori_data, parameters)

        # Discriminative score for the sequence
        metric_iteration = 5
        
        discriminative_scores = [
            t_discriminative_score_metrics(ori_data, generated_data, iterations=200, batch_size=batch_size, patience=10)
            for _ in range(metric_iteration)
        ]
        
        final_discri_score = np.round(np.mean(discriminative_scores), 4)
        print(f'{data_type.capitalize()} Discriminative score: {final_discri_score}')
        
        # Predictive score for the sequence
        predictive_scores = [
            t_predictive_score_metrics(ori_data, generated_data, epochs=50, batch_size=batch_size, n_splits=5)
            for _ in range(metric_iteration)
        ]
        
        final_pred_score = np.round(np.mean(predictive_scores), 4)
        print(f'{data_type.capitalize()} Predictive score: {final_pred_score}')
        
        # Combine the scores (you can adjust the weight of each score if needed)
        combined_score = final_discri_score + final_pred_score
        combined_scores.append(combined_score)
        
        if trial.should_prune():
            raise optuna.TrialPruned()
            
    # Compute average score and store trial result immediately
    average_combined_score = np.mean(combined_scores)
    
    # Create a dictionary for the current trial's results
    trial_results = {
        'trial_number': trial.number,
        'params': trial.params,
        'combined_score': average_combined_score
    }

    # Save trial result to a JSON file after every trial
    with open('timeganlogs/rogue_hold.json', 'a') as json_file:
        json.dump(trial_results, json_file)
        json_file.write('\n')  # Write each result on a new line for easier reading and appending
    
    # Return the average combined score
    return average_combined_score


# Optuna Study Setup for Daily Sequence Optimization
study_daily = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner())
study_daily.optimize(lambda trial: objective(trial, 'daily'), n_trials=3)  # Number of trials for daily optimization

# Optuna Study Setup for Time-of-Day Sequence Optimization (if needed)
# study_time_of_day = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner())
# study_time_of_day.optimize(lambda trial: objective(trial, 'time_of_day'), n_trials=20)  # Number of trials for time_of_day optimization

# Best hyperparameters and result for daily sequence
print("Best hyperparameters for daily sequence:", study_daily.best_params)
print("Best combined score for daily sequence:", study_daily.best_value)

# Store the best results
best_model_stats = {
    'best_params': study_daily.best_params
}

with open('timeganlogs/best_timegan_model_stats_rogue_hold.json', 'w') as json_file:
    json.dump(best_model_stats, json_file)
# Out:
# [I 2025-03-06 15:39:44,675] A new study created in memory with name: no-name-4dbef573-ea8b-49f3-b67f-0dfdcc9fa45f
# Processing TimeGAN for realKnownCause/rogue_agent_key_hold.csv (daily sequence)
# Training completed
# Epoch 1/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.9022 - loss: 0.6871 - val_accuracy: 1.0000 - val_loss: 0.6714
# Epoch 2/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9618 - loss: 0.6591 - val_accuracy: 1.0000 - val_loss: 0.6054
# Epoch 3/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9982 - loss: 0.5731 - val_accuracy: 0.9911 - val_loss: 0.4657
# Epoch 4/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9940 - loss: 0.4262 - val_accuracy: 0.9921 - val_loss: 0.3333
# Epoch 5/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9977 - loss: 0.3076 - val_accuracy: 1.0000 - val_loss: 0.2517
# Epoch 6/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.2387 - val_accuracy: 1.0000 - val_loss: 0.2077
# Epoch 7/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.1997 - val_accuracy: 1.0000 - val_loss: 0.1793
# Epoch 8/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.1737 - val_accuracy: 1.0000 - val_loss: 0.1589
# Epoch 9/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.1547 - val_accuracy: 1.0000 - val_loss: 0.1431
# Epoch 10/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.1398 - val_accuracy: 1.0000 - val_loss: 0.1304
# Epoch 11/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.1276 - val_accuracy: 1.0000 - val_loss: 0.1197
# Epoch 12/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.1173 - val_accuracy: 1.0000 - val_loss: 0.1106
# Epoch 13/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.1085 - val_accuracy: 1.0000 - val_loss: 0.1026
# Epoch 14/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.1008 - val_accuracy: 1.0000 - val_loss: 0.0956
# Epoch 15/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0940 - val_accuracy: 1.0000 - val_loss: 0.0894
# Epoch 16/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0879 - val_accuracy: 1.0000 - val_loss: 0.0838
# Epoch 17/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0825 - val_accuracy: 1.0000 - val_loss: 0.0787
# Epoch 18/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0775 - val_accuracy: 1.0000 - val_loss: 0.0741
# Epoch 19/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0730 - val_accuracy: 1.0000 - val_loss: 0.0699
# Epoch 20/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0689 - val_accuracy: 1.0000 - val_loss: 0.0660
# Epoch 21/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0651 - val_accuracy: 1.0000 - val_loss: 0.0625
# Epoch 22/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0616 - val_accuracy: 1.0000 - val_loss: 0.0592
# Epoch 23/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0584 - val_accuracy: 1.0000 - val_loss: 0.0561
# Epoch 24/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0554 - val_accuracy: 1.0000 - val_loss: 0.0533
# Epoch 25/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0526 - val_accuracy: 1.0000 - val_loss: 0.0506
# Epoch 26/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0500 - val_accuracy: 1.0000 - val_loss: 0.0482
# Epoch 27/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0476 - val_accuracy: 1.0000 - val_loss: 0.0458
# Epoch 28/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0453 - val_accuracy: 1.0000 - val_loss: 0.0437
# Epoch 29/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0432 - val_accuracy: 1.0000 - val_loss: 0.0416
# Epoch 30/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0412 - val_accuracy: 1.0000 - val_loss: 0.0397
# Epoch 31/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0393 - val_accuracy: 1.0000 - val_loss: 0.0379
# Epoch 32/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0375 - val_accuracy: 1.0000 - val_loss: 0.0362
# Epoch 33/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0358 - val_accuracy: 1.0000 - val_loss: 0.0346
# Epoch 34/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0343 - val_accuracy: 1.0000 - val_loss: 0.0331
# Epoch 35/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0328 - val_accuracy: 1.0000 - val_loss: 0.0317
# Epoch 36/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0314 - val_accuracy: 1.0000 - val_loss: 0.0303
# Epoch 37/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0300 - val_accuracy: 1.0000 - val_loss: 0.0291
# Epoch 38/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 1.0000 - val_loss: 0.0278
# Epoch 39/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0275 - val_accuracy: 1.0000 - val_loss: 0.0267
# Epoch 40/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0264 - val_accuracy: 1.0000 - val_loss: 0.0256
# Epoch 41/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 0.0245
# Epoch 42/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0243 - val_accuracy: 1.0000 - val_loss: 0.0235
# Epoch 43/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0233 - val_accuracy: 1.0000 - val_loss: 0.0226
# Epoch 44/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 1.0000 - val_loss: 0.0217
# Epoch 45/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 0.0208
# Epoch 46/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0206 - val_accuracy: 1.0000 - val_loss: 0.0200
# Epoch 47/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0198 - val_accuracy: 1.0000 - val_loss: 0.0192
# Epoch 48/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 0.0185
# Epoch 49/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 1.0000 - val_loss: 0.0178
# Epoch 50/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0176 - val_accuracy: 1.0000 - val_loss: 0.0171
# Epoch 51/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 1.0000 - val_loss: 0.0164
# Epoch 52/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 0.0158
# Epoch 53/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 1.0000 - val_loss: 0.0152
# Epoch 54/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 0.0146
# Epoch 55/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 1.0000 - val_loss: 0.0141
# Epoch 56/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 57/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 58/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 1.0000 - val_loss: 0.0125
# Epoch 59/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 60/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 61/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 0.0112
# Epoch 62/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0108
# Epoch 63/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 64/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 65/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 0.0097
# Epoch 66/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 67/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 68/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 69/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 70/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 71/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 72/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 73/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 74/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 75/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 76/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 77/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 78/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 79/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 80/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 81/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 82/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 83/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 84/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 85/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 86/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 87/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 88/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 89/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 90/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 91/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 92/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 93/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 94/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 95/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 96/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 97/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 98/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 99/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 100/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 101/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 102/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 103/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 104/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 105/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 106/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 107/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 108/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 109/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 110/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 111/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 112/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 113/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 114/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 115/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 116/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 117/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 118/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 119/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 120/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 121/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 122/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 123/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 124/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 125/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 126/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 127/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 128/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 129/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 9.8981e-04
# Epoch 130/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 9.8134e-04 - val_accuracy: 1.0000 - val_loss: 9.5590e-04
# Epoch 131/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 9.4769e-04 - val_accuracy: 1.0000 - val_loss: 9.2316e-04
# Epoch 132/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 9.1529e-04 - val_accuracy: 1.0000 - val_loss: 8.9154e-04
# Epoch 133/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 8.8389e-04 - val_accuracy: 1.0000 - val_loss: 8.6100e-04
# Epoch 134/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 8.5360e-04 - val_accuracy: 1.0000 - val_loss: 8.3151e-04
# Epoch 135/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 8.2439e-04 - val_accuracy: 1.0000 - val_loss: 8.0304e-04
# Epoch 136/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 7.9615e-04 - val_accuracy: 1.0000 - val_loss: 7.7554e-04
# Epoch 137/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 7.6887e-04 - val_accuracy: 1.0000 - val_loss: 7.4898e-04
# Epoch 138/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 7.4253e-04 - val_accuracy: 1.0000 - val_loss: 7.2333e-04
# Epoch 139/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 7.1714e-04 - val_accuracy: 1.0000 - val_loss: 6.9856e-04
# Epoch 140/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 6.9257e-04 - val_accuracy: 1.0000 - val_loss: 6.7463e-04
# Epoch 141/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 6.6885e-04 - val_accuracy: 1.0000 - val_loss: 6.5153e-04
# Epoch 142/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 6.4595e-04 - val_accuracy: 1.0000 - val_loss: 6.2921e-04
# Epoch 143/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 6.2382e-04 - val_accuracy: 1.0000 - val_loss: 6.0766e-04
# Epoch 144/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 6.0245e-04 - val_accuracy: 1.0000 - val_loss: 5.8685e-04
# Epoch 145/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 5.8182e-04 - val_accuracy: 1.0000 - val_loss: 5.6674e-04
# Epoch 146/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 5.6189e-04 - val_accuracy: 1.0000 - val_loss: 5.4733e-04
# Epoch 147/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 5.4264e-04 - val_accuracy: 1.0000 - val_loss: 5.2858e-04
# Epoch 148/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 5.2405e-04 - val_accuracy: 1.0000 - val_loss: 5.1047e-04
# Epoch 149/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 5.0611e-04 - val_accuracy: 1.0000 - val_loss: 4.9299e-04
# Epoch 150/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 4.8876e-04 - val_accuracy: 1.0000 - val_loss: 4.7610e-04
# Epoch 151/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 4.7202e-04 - val_accuracy: 1.0000 - val_loss: 4.5978e-04
# Epoch 152/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 4.5584e-04 - val_accuracy: 1.0000 - val_loss: 4.4403e-04
# Epoch 153/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 4.4022e-04 - val_accuracy: 1.0000 - val_loss: 4.2882e-04
# Epoch 154/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 4.2513e-04 - val_accuracy: 1.0000 - val_loss: 4.1413e-04
# Epoch 155/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 4.1057e-04 - val_accuracy: 1.0000 - val_loss: 3.9994e-04
# Epoch 156/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.9650e-04 - val_accuracy: 1.0000 - val_loss: 3.8623e-04
# Epoch 157/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 3.8290e-04 - val_accuracy: 1.0000 - val_loss: 3.7300e-04
# Epoch 158/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 3.6978e-04 - val_accuracy: 1.0000 - val_loss: 3.6022e-04
# Epoch 159/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 3.5711e-04 - val_accuracy: 1.0000 - val_loss: 3.4787e-04
# Epoch 160/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 3.4488e-04 - val_accuracy: 1.0000 - val_loss: 3.3595e-04
# Epoch 161/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.3306e-04 - val_accuracy: 1.0000 - val_loss: 3.2444e-04
# Epoch 162/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 3.2164e-04 - val_accuracy: 1.0000 - val_loss: 3.1333e-04
# Epoch 163/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.1063e-04 - val_accuracy: 1.0000 - val_loss: 3.0260e-04
# Epoch 164/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 2.9999e-04 - val_accuracy: 1.0000 - val_loss: 2.9224e-04
# Epoch 165/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.8971e-04 - val_accuracy: 1.0000 - val_loss: 2.8223e-04
# Epoch 166/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.7979e-04 - val_accuracy: 1.0000 - val_loss: 2.7257e-04
# Epoch 167/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 2.7022e-04 - val_accuracy: 1.0000 - val_loss: 2.6323e-04
# Epoch 168/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.6096e-04 - val_accuracy: 1.0000 - val_loss: 2.5422e-04
# Epoch 169/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 2.5203e-04 - val_accuracy: 1.0000 - val_loss: 2.4552e-04
# Epoch 170/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 2.4340e-04 - val_accuracy: 1.0000 - val_loss: 2.3711e-04
# Epoch 171/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.3506e-04 - val_accuracy: 1.0000 - val_loss: 2.2899e-04
# Epoch 172/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.2697e-04 - val_accuracy: 1.0000 - val_loss: 2.2115e-04
# Epoch 173/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.1920e-04 - val_accuracy: 1.0000 - val_loss: 2.1358e-04
# Epoch 174/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.1170e-04 - val_accuracy: 1.0000 - val_loss: 2.0626e-04
# Epoch 175/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.0446e-04 - val_accuracy: 1.0000 - val_loss: 1.9920e-04
# Epoch 176/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 1.9746e-04 - val_accuracy: 1.0000 - val_loss: 1.9238e-04
# Epoch 177/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.9070e-04 - val_accuracy: 1.0000 - val_loss: 1.8579e-04
# Epoch 178/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 1.8417e-04 - val_accuracy: 1.0000 - val_loss: 1.7943e-04
# Epoch 179/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.7786e-04 - val_accuracy: 1.0000 - val_loss: 1.7328e-04
# Epoch 180/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.7177e-04 - val_accuracy: 1.0000 - val_loss: 1.6735e-04
# Epoch 181/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.6589e-04 - val_accuracy: 1.0000 - val_loss: 1.6162e-04
# Epoch 182/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.6021e-04 - val_accuracy: 1.0000 - val_loss: 1.5608e-04
# Epoch 183/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 1.5472e-04 - val_accuracy: 1.0000 - val_loss: 1.5073e-04
# Epoch 184/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 1.4942e-04 - val_accuracy: 1.0000 - val_loss: 1.4557e-04
# Epoch 185/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.4431e-04 - val_accuracy: 1.0000 - val_loss: 1.4059e-04
# Epoch 186/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 1.3937e-04 - val_accuracy: 1.0000 - val_loss: 1.3577e-04
# Epoch 187/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.3459e-04 - val_accuracy: 1.0000 - val_loss: 1.3112e-04
# Epoch 188/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 1.2998e-04 - val_accuracy: 1.0000 - val_loss: 1.2663e-04
# Epoch 189/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.2553e-04 - val_accuracy: 1.0000 - val_loss: 1.2229e-04
# Epoch 190/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 1.2123e-04 - val_accuracy: 1.0000 - val_loss: 1.1810e-04
# Epoch 191/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.1708e-04 - val_accuracy: 1.0000 - val_loss: 1.1406e-04
# Epoch 192/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.1307e-04 - val_accuracy: 1.0000 - val_loss: 1.1015e-04
# Epoch 193/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.0920e-04 - val_accuracy: 1.0000 - val_loss: 1.0637e-04
# Epoch 194/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.0545e-04 - val_accuracy: 1.0000 - val_loss: 1.0273e-04
# Epoch 195/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.0184e-04 - val_accuracy: 1.0000 - val_loss: 9.9210e-05
# Epoch 196/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 9.8353e-05 - val_accuracy: 1.0000 - val_loss: 9.5811e-05
# Epoch 197/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 9.4984e-05 - val_accuracy: 1.0000 - val_loss: 9.2529e-05
# Epoch 198/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 9.1730e-05 - val_accuracy: 1.0000 - val_loss: 8.9358e-05
# Epoch 199/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 8.8588e-05 - val_accuracy: 1.0000 - val_loss: 8.6297e-05
# Epoch 200/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 8.5553e-05 - val_accuracy: 1.0000 - val_loss: 8.3340e-05
# Epoch 1/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.5839 - loss: 0.6899 - val_accuracy: 0.7307 - val_loss: 0.6851
# Epoch 2/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8882 - loss: 0.6822 - val_accuracy: 0.9762 - val_loss: 0.6691
# Epoch 3/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9802 - loss: 0.6609 - val_accuracy: 0.9842 - val_loss: 0.6256
# Epoch 4/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9901 - loss: 0.6027 - val_accuracy: 0.9950 - val_loss: 0.5023
# Epoch 5/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9942 - loss: 0.4454 - val_accuracy: 0.9916 - val_loss: 0.2788
# Epoch 6/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9911 - loss: 0.2453 - val_accuracy: 0.9921 - val_loss: 0.1784
# Epoch 7/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9976 - loss: 0.1637 - val_accuracy: 1.0000 - val_loss: 0.1315
# Epoch 8/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.1235 - val_accuracy: 1.0000 - val_loss: 0.1060
# Epoch 9/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.1015 - val_accuracy: 1.0000 - val_loss: 0.0907
# Epoch 10/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0875 - val_accuracy: 1.0000 - val_loss: 0.0796
# Epoch 11/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0771 - val_accuracy: 1.0000 - val_loss: 0.0709
# Epoch 12/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0690 - val_accuracy: 1.0000 - val_loss: 0.0640
# Epoch 13/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0624 - val_accuracy: 1.0000 - val_loss: 0.0582
# Epoch 14/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0569 - val_accuracy: 1.0000 - val_loss: 0.0532
# Epoch 15/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0521 - val_accuracy: 1.0000 - val_loss: 0.0490
# Epoch 16/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0481 - val_accuracy: 1.0000 - val_loss: 0.0454
# Epoch 17/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0446 - val_accuracy: 1.0000 - val_loss: 0.0422
# Epoch 18/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0414 - val_accuracy: 1.0000 - val_loss: 0.0394
# Epoch 19/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0387 - val_accuracy: 1.0000 - val_loss: 0.0369
# Epoch 20/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0363 - val_accuracy: 1.0000 - val_loss: 0.0346
# Epoch 21/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0341 - val_accuracy: 1.0000 - val_loss: 0.0326
# Epoch 22/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0322 - val_accuracy: 1.0000 - val_loss: 0.0308
# Epoch 23/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0304 - val_accuracy: 1.0000 - val_loss: 0.0292
# Epoch 24/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0288 - val_accuracy: 1.0000 - val_loss: 0.0277
# Epoch 25/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0273 - val_accuracy: 1.0000 - val_loss: 0.0263
# Epoch 26/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 1.0000 - val_loss: 0.0250
# Epoch 27/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0247 - val_accuracy: 1.0000 - val_loss: 0.0238
# Epoch 28/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0236 - val_accuracy: 1.0000 - val_loss: 0.0227
# Epoch 29/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0225 - val_accuracy: 1.0000 - val_loss: 0.0217
# Epoch 30/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0214 - val_accuracy: 1.0000 - val_loss: 0.0207
# Epoch 31/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0205 - val_accuracy: 1.0000 - val_loss: 0.0198
# Epoch 32/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 1.0000 - val_loss: 0.0189
# Epoch 33/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 1.0000 - val_loss: 0.0181
# Epoch 34/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0179 - val_accuracy: 1.0000 - val_loss: 0.0173
# Epoch 35/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0172 - val_accuracy: 1.0000 - val_loss: 0.0166
# Epoch 36/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 1.0000 - val_loss: 0.0159
# Epoch 37/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 1.0000 - val_loss: 0.0152
# Epoch 38/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 0.0146
# Epoch 39/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 40/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 41/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 0.0129
# Epoch 42/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 1.0000 - val_loss: 0.0124
# Epoch 43/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 1.0000 - val_loss: 0.0119
# Epoch 44/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 0.0115
# Epoch 45/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 0.0110
# Epoch 46/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 1.0000 - val_loss: 0.0106
# Epoch 47/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 0.0102
# Epoch 48/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 49/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 50/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 51/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 52/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 53/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 0.0081
# Epoch 54/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 55/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 56/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 57/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 58/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 59/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 60/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 61/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 62/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 63/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 64/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 65/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 66/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 67/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 68/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 69/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 70/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 71/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 72/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 73/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 74/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 75/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 76/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 77/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 78/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 79/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 80/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 81/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 82/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 83/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 84/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 85/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 86/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 87/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 88/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 89/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 90/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 91/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 92/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 93/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 94/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 95/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 96/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 97/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 98/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 99/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 100/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 101/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 102/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 103/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 104/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 105/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 106/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 107/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 108/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 109/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 110/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 111/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 112/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 9.9206e-04 - val_accuracy: 1.0000 - val_loss: 9.6615e-04
# Epoch 113/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 9.5782e-04 - val_accuracy: 1.0000 - val_loss: 9.3282e-04
# Epoch 114/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 9.2477e-04 - val_accuracy: 1.0000 - val_loss: 9.0068e-04
# Epoch 115/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 8.9290e-04 - val_accuracy: 1.0000 - val_loss: 8.6965e-04
# Epoch 116/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 8.6215e-04 - val_accuracy: 1.0000 - val_loss: 8.3969e-04
# Epoch 117/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 8.3245e-04 - val_accuracy: 1.0000 - val_loss: 8.1076e-04
# Epoch 118/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 8.0378e-04 - val_accuracy: 1.0000 - val_loss: 7.8284e-04
# Epoch 119/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 7.7610e-04 - val_accuracy: 1.0000 - val_loss: 7.5588e-04
# Epoch 120/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 7.4937e-04 - val_accuracy: 1.0000 - val_loss: 7.2984e-04
# Epoch 121/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 7.2357e-04 - val_accuracy: 1.0000 - val_loss: 7.0471e-04
# Epoch 122/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 6.9868e-04 - val_accuracy: 1.0000 - val_loss: 6.8044e-04
# Epoch 123/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 6.7462e-04 - val_accuracy: 1.0000 - val_loss: 6.5704e-04
# Epoch 124/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 6.5141e-04 - val_accuracy: 1.0000 - val_loss: 6.3444e-04
# Epoch 125/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 6.2904e-04 - val_accuracy: 1.0000 - val_loss: 6.1263e-04
# Epoch 126/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 6.0740e-04 - val_accuracy: 1.0000 - val_loss: 5.9156e-04
# Epoch 127/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 5.8651e-04 - val_accuracy: 1.0000 - val_loss: 5.7122e-04
# Epoch 128/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 5.6635e-04 - val_accuracy: 1.0000 - val_loss: 5.5159e-04
# Epoch 129/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 5.4686e-04 - val_accuracy: 1.0000 - val_loss: 5.3262e-04
# Epoch 130/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 5.2806e-04 - val_accuracy: 1.0000 - val_loss: 5.1431e-04
# Epoch 131/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 5.0991e-04 - val_accuracy: 1.0000 - val_loss: 4.9664e-04
# Epoch 132/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 4.9238e-04 - val_accuracy: 1.0000 - val_loss: 4.7957e-04
# Epoch 133/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 4.7545e-04 - val_accuracy: 1.0000 - val_loss: 4.6309e-04
# Epoch 134/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 4.5911e-04 - val_accuracy: 1.0000 - val_loss: 4.4717e-04
# Epoch 135/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 4.4334e-04 - val_accuracy: 1.0000 - val_loss: 4.3181e-04
# Epoch 136/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 4.2810e-04 - val_accuracy: 1.0000 - val_loss: 4.1697e-04
# Epoch 137/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 4.1340e-04 - val_accuracy: 1.0000 - val_loss: 4.0264e-04
# Epoch 138/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 3.9919e-04 - val_accuracy: 1.0000 - val_loss: 3.8881e-04
# Epoch 139/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 3.8547e-04 - val_accuracy: 1.0000 - val_loss: 3.7545e-04
# Epoch 140/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.7223e-04 - val_accuracy: 1.0000 - val_loss: 3.6255e-04
# Epoch 141/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 3.5944e-04 - val_accuracy: 1.0000 - val_loss: 3.5010e-04
# Epoch 142/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.4710e-04 - val_accuracy: 1.0000 - val_loss: 3.3807e-04
# Epoch 143/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.3519e-04 - val_accuracy: 1.0000 - val_loss: 3.2646e-04
# Epoch 144/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 3.2367e-04 - val_accuracy: 1.0000 - val_loss: 3.1525e-04
# Epoch 145/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.1255e-04 - val_accuracy: 1.0000 - val_loss: 3.0442e-04
# Epoch 146/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 3.0182e-04 - val_accuracy: 1.0000 - val_loss: 2.9397e-04
# Epoch 147/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.9145e-04 - val_accuracy: 1.0000 - val_loss: 2.8387e-04
# Epoch 148/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 2.8144e-04 - val_accuracy: 1.0000 - val_loss: 2.7412e-04
# Epoch 149/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.7178e-04 - val_accuracy: 1.0000 - val_loss: 2.6471e-04
# Epoch 150/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 2.6244e-04 - val_accuracy: 1.0000 - val_loss: 2.5562e-04
# Epoch 151/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 2.5343e-04 - val_accuracy: 1.0000 - val_loss: 2.4685e-04
# Epoch 152/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.4473e-04 - val_accuracy: 1.0000 - val_loss: 2.3837e-04
# Epoch 153/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.3632e-04 - val_accuracy: 1.0000 - val_loss: 2.3019e-04
# Epoch 154/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.2821e-04 - val_accuracy: 1.0000 - val_loss: 2.2229e-04
# Epoch 155/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.2037e-04 - val_accuracy: 1.0000 - val_loss: 2.1466e-04
# Epoch 156/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 2.1281e-04 - val_accuracy: 1.0000 - val_loss: 2.0729e-04
# Epoch 157/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 2.0551e-04 - val_accuracy: 1.0000 - val_loss: 2.0017e-04
# Epoch 158/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 1.9845e-04 - val_accuracy: 1.0000 - val_loss: 1.9330e-04
# Epoch 159/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 1.9164e-04 - val_accuracy: 1.0000 - val_loss: 1.8667e-04
# Epoch 160/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 1.8506e-04 - val_accuracy: 1.0000 - val_loss: 1.8026e-04
# Epoch 161/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 1.7871e-04 - val_accuracy: 1.0000 - val_loss: 1.7407e-04
# Epoch 162/200
# ...
# Epoch 66/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0197 - val_accuracy: 1.0000 - val_loss: 0.0191
# Epoch 67/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 0.0183
# Epoch 68/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0181 - val_accuracy: 1.0000 - val_loss: 0.0176
# Epoch 69/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 1.0000 - val_loss: 0.0169
# Epoch 70/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0167 - val_accuracy: 1.0000 - val_loss: 0.0162
# Epoch 71/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0161 - val_accuracy: 1.0000 - val_loss: 0.0156
# Epoch 72/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 1.0000 - val_loss: 0.0150
# Epoch 73/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 0.0144
# Epoch 74/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 0.0139
# Epoch 75/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 0.0133
# Epoch 76/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 0.0128
# Epoch 77/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 1.0000 - val_loss: 0.0123
# Epoch 78/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 0.0119
# Epoch 79/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 80/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 0.0110
# Epoch 81/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 1.0000 - val_loss: 0.0106
# Epoch 82/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 0.0102
# Epoch 83/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 84/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0095
# Epoch 85/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 86/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0088
# Epoch 87/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 88/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 89/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 90/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 91/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 92/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 93/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 94/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 95/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 96/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 97/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 98/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 99/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 100/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 101/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 102/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 103/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 104/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 105/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 106/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 107/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 108/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 109/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 110/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 111/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 112/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 113/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 114/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 115/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 116/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 117/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 118/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 119/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 120/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 121/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 122/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 123/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 124/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 125/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 126/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 127/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 128/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 129/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 130/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 131/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 132/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 133/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 134/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 135/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 136/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 137/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 138/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 139/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 140/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 141/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 142/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 143/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 144/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 145/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 146/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 147/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 9.9939e-04
# Epoch 148/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 9.9075e-04 - val_accuracy: 1.0000 - val_loss: 9.6499e-04
# Epoch 149/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 9.5666e-04 - val_accuracy: 1.0000 - val_loss: 9.3178e-04
# Epoch 150/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 9.2374e-04 - val_accuracy: 1.0000 - val_loss: 8.9973e-04
# Epoch 151/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 8.9196e-04 - val_accuracy: 1.0000 - val_loss: 8.6880e-04
# Epoch 152/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 8.6129e-04 - val_accuracy: 1.0000 - val_loss: 8.3893e-04
# Epoch 153/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 8.3169e-04 - val_accuracy: 1.0000 - val_loss: 8.1009e-04
# Epoch 154/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 8.0309e-04 - val_accuracy: 1.0000 - val_loss: 7.8225e-04
# Epoch 155/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 7.7547e-04 - val_accuracy: 1.0000 - val_loss: 7.5536e-04
# Epoch 156/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 7.4881e-04 - val_accuracy: 1.0000 - val_loss: 7.2939e-04
# Epoch 157/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 7.2307e-04 - val_accuracy: 1.0000 - val_loss: 7.0432e-04
# Epoch 158/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 6.9820e-04 - val_accuracy: 1.0000 - val_loss: 6.8012e-04
# Epoch 159/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 6.7421e-04 - val_accuracy: 1.0000 - val_loss: 6.5674e-04
# Epoch 160/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 6.5105e-04 - val_accuracy: 1.0000 - val_loss: 6.3417e-04
# Epoch 161/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 6.2868e-04 - val_accuracy: 1.0000 - val_loss: 6.1238e-04
# Epoch 162/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 6.0708e-04 - val_accuracy: 1.0000 - val_loss: 5.9134e-04
# Epoch 163/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 5.8623e-04 - val_accuracy: 1.0000 - val_loss: 5.7104e-04
# Epoch 164/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 5.6611e-04 - val_accuracy: 1.0000 - val_loss: 5.5144e-04
# Epoch 165/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 5.4668e-04 - val_accuracy: 1.0000 - val_loss: 5.3252e-04
# Epoch 166/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 5.2791e-04 - val_accuracy: 1.0000 - val_loss: 5.1424e-04
# Epoch 167/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 5.0979e-04 - val_accuracy: 1.0000 - val_loss: 4.9659e-04
# Epoch 168/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 4.9230e-04 - val_accuracy: 1.0000 - val_loss: 4.7955e-04
# Epoch 169/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 4.7540e-04 - val_accuracy: 1.0000 - val_loss: 4.6309e-04
# Epoch 170/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 4.5908e-04 - val_accuracy: 1.0000 - val_loss: 4.4720e-04
# Epoch 171/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 4.4334e-04 - val_accuracy: 1.0000 - val_loss: 4.3186e-04
# Epoch 172/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 4.2805e-04 - val_accuracy: 1.0000 - val_loss: 4.1704e-04
# Epoch 173/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 4.1337e-04 - val_accuracy: 1.0000 - val_loss: 4.0273e-04
# Epoch 174/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.9919e-04 - val_accuracy: 1.0000 - val_loss: 3.8891e-04
# Epoch 175/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.8550e-04 - val_accuracy: 1.0000 - val_loss: 3.7557e-04
# Epoch 176/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.7228e-04 - val_accuracy: 1.0000 - val_loss: 3.6268e-04
# Epoch 177/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.5952e-04 - val_accuracy: 1.0000 - val_loss: 3.5024e-04
# Epoch 178/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.4718e-04 - val_accuracy: 1.0000 - val_loss: 3.3822e-04
# Epoch 179/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.3527e-04 - val_accuracy: 1.0000 - val_loss: 3.2662e-04
# Epoch 180/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.2377e-04 - val_accuracy: 1.0000 - val_loss: 3.1542e-04
# Epoch 181/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.1267e-04 - val_accuracy: 1.0000 - val_loss: 3.0461e-04
# Epoch 182/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 3.0196e-04 - val_accuracy: 1.0000 - val_loss: 2.9416e-04
# Epoch 183/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 2.9160e-04 - val_accuracy: 1.0000 - val_loss: 2.8408e-04
# Epoch 184/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 2.8161e-04 - val_accuracy: 1.0000 - val_loss: 2.7434e-04
# Epoch 185/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 2.7196e-04 - val_accuracy: 1.0000 - val_loss: 2.6494e-04
# Epoch 186/200
# 81/84 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 2.6275e-04

# %%
def objective(trial, data_type):
    """Optimize hyperparameters using Optuna for both sequences (daily and time_of_day)."""
    
    # Sample hyperparameters
    hidden_dim = trial.suggest_int('hidden_dim', 10, 50, step=10)
    num_layers = trial.suggest_int('num_layer', 2, 3)
    batch_size = trial.suggest_int('batch_size', 32, 256, step=32)
    module = trial.suggest_categorical('module', ['gru', 'lstm'])
    
    combined_scores = []
    
    for window_size, preprocessed_df, file_name in zip(window_sizes, preprocessed_dfs, file_names):
        if file_name != 'realKnownCause/cpu_utilization_asg_misconfiguration.csv':
            continue 
        print(f'Processing TimeGAN for {file_name} ({data_type} sequence)')
        name = file_name.split('/')[-1].split('.')[0]
        data = np.array(preprocessed_df['value']).reshape(-1, 1)
        
        # Prepare sequences based on the data_type (daily or time_of_day)
        if data_type == 'daily':
            time_series = [data[i:i + window_size['daily']] for i in range(len(data) - window_size['daily'])]
        else:  # 'time_of_day'
            time_series = [data[i:i + window_size['time_of_day']] for i in range(len(data) - window_size['time_of_day'])]
        
        ori_data = np.array(time_series)

        # Parameters for the model
        parameters = {
            "hidden_dim": hidden_dim,
            "num_layer": num_layers,
            "iterations": 10000,
            "batch_size": batch_size,
            "module": module
        }

        # Generate synthetic data for the sequence
        generated_data = timegan(ori_data, parameters)

        # Discriminative score for the sequence
        metric_iteration = 5
        
        discriminative_scores = [
            t_discriminative_score_metrics(ori_data, generated_data, iterations=200, batch_size=batch_size, patience=10)
            for _ in range(metric_iteration)
        ]
        
        final_discri_score = np.round(np.mean(discriminative_scores), 4)
        print(f'{data_type.capitalize()} Discriminative score: {final_discri_score}')
        
        # Predictive score for the sequence
        predictive_scores = [
            t_predictive_score_metrics(ori_data, generated_data, epochs=50, batch_size=batch_size, n_splits=5)
            for _ in range(metric_iteration)
        ]
        
        final_pred_score = np.round(np.mean(predictive_scores), 4)
        print(f'{data_type.capitalize()} Predictive score: {final_pred_score}')
        
        # Combine the scores (you can adjust the weight of each score if needed)
        combined_score = final_discri_score + final_pred_score
        combined_scores.append(combined_score)
        
        if trial.should_prune():
            raise optuna.TrialPruned()
            
    # Return the average combined score
    return np.mean(combined_scores)


# Optuna Study Setup for Daily Sequence Optimization
study_daily = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner())
study_daily.optimize(lambda trial: objective(trial, 'daily'), n_trials=1)  # Number of trials for daily optimization

# Optuna Study Setup for Time-of-Day Sequence Optimization
#study_time_of_day = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner())
#study_time_of_day.optimize(lambda trial: objective(trial, 'time_of_day'), n_trials=20)  # Number of trials for time_of_day optimization

# Best hyperparameters and result for daily sequence
print("Best hyperparameters for daily sequence:", study_daily.best_params)
print("Best combined score for daily sequence:", study_daily.best_value)

# Store the best results
best_model_stats = {
    'best_params': best_params
}

with open('timeganlogs/best_timegan_model_stats_cpu.json', 'w') as json_file:
    json.dump(best_model_stats, json_file)
# Out:
# [I 2025-03-05 09:46:11,336] A new study created in memory with name: no-name-876b558d-cb88-4927-8bca-3f20f5401544
# Processing TimeGAN for realKnownCause/cpu_utilization_asg_misconfiguration.csv (daily sequence)
# Training completed
# Epoch 1/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 13s 14ms/step - accuracy: 0.6124 - loss: 0.6425 - val_accuracy: 0.9979 - val_loss: 0.2107
# Epoch 2/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.8440 - loss: 0.4152 - val_accuracy: 1.0000 - val_loss: 0.1153
# Epoch 3/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9955 - loss: 0.1109 - val_accuracy: 1.0000 - val_loss: 0.0676
# Epoch 4/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0601 - val_accuracy: 1.0000 - val_loss: 0.0422
# Epoch 5/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0380 - val_accuracy: 1.0000 - val_loss: 0.0275
# Epoch 6/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.8623 - loss: 0.4360 - val_accuracy: 1.0000 - val_loss: 0.0641
# Epoch 7/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9907 - loss: 0.0743 - val_accuracy: 1.0000 - val_loss: 0.0357
# Epoch 8/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9959 - loss: 0.0447 - val_accuracy: 1.0000 - val_loss: 0.0248
# Epoch 9/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9979 - loss: 0.0302 - val_accuracy: 1.0000 - val_loss: 0.0181
# Epoch 10/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9991 - loss: 0.0203 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 11/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9993 - loss: 0.0154 - val_accuracy: 1.0000 - val_loss: 0.0101
# Epoch 12/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9979 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 13/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9978 - loss: 0.0176 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 14/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 15/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 16/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 17/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 18/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 19/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 8.1879e-04
# Epoch 20/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.5005e-04 - val_accuracy: 1.0000 - val_loss: 5.6919e-04
# Epoch 21/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 5.2112e-04 - val_accuracy: 1.0000 - val_loss: 3.9487e-04
# Epoch 22/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 3.6140e-04 - val_accuracy: 1.0000 - val_loss: 2.7359e-04
# Epoch 23/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.5035e-04 - val_accuracy: 1.0000 - val_loss: 1.8943e-04
# Epoch 24/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.7331e-04 - val_accuracy: 1.0000 - val_loss: 1.3110e-04
# Epoch 25/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.1995e-04 - val_accuracy: 1.0000 - val_loss: 9.0728e-05
# Epoch 26/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 8.3000e-05 - val_accuracy: 1.0000 - val_loss: 6.2758e-05
# Epoch 27/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 5.7413e-05 - val_accuracy: 1.0000 - val_loss: 4.3414e-05
# Epoch 28/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 3.9717e-05 - val_accuracy: 1.0000 - val_loss: 3.0035e-05
# Epoch 29/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.7478e-05 - val_accuracy: 1.0000 - val_loss: 2.0781e-05
# Epoch 30/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.9013e-05 - val_accuracy: 1.0000 - val_loss: 1.4385e-05
# Epoch 31/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.3162e-05 - val_accuracy: 1.0000 - val_loss: 9.9610e-06
# Epoch 32/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 9.1152e-06 - val_accuracy: 1.0000 - val_loss: 6.8991e-06
# Epoch 33/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 6.3134e-06 - val_accuracy: 1.0000 - val_loss: 4.7798e-06
# Epoch 34/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 4.3748e-06 - val_accuracy: 1.0000 - val_loss: 3.3140e-06
# Epoch 35/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 3.0338e-06 - val_accuracy: 1.0000 - val_loss: 2.3000e-06
# Epoch 36/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.1062e-06 - val_accuracy: 1.0000 - val_loss: 1.5986e-06
# Epoch 37/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.4645e-06 - val_accuracy: 1.0000 - val_loss: 1.1134e-06
# Epoch 38/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.0206e-06 - val_accuracy: 1.0000 - val_loss: 7.7769e-07
# Epoch 39/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.1343e-07 - val_accuracy: 1.0000 - val_loss: 5.4541e-07
# Epoch 40/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 5.0096e-07 - val_accuracy: 1.0000 - val_loss: 3.8434e-07
# Epoch 41/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 3.5387e-07 - val_accuracy: 1.0000 - val_loss: 2.7303e-07
# Epoch 42/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.5196e-07 - val_accuracy: 1.0000 - val_loss: 1.9636e-07
# Epoch 43/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.8171e-07 - val_accuracy: 1.0000 - val_loss: 1.4260e-07
# Epoch 44/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.3283e-07 - val_accuracy: 1.0000 - val_loss: 1.0564e-07
# Epoch 45/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 9.7960e-08 - val_accuracy: 1.0000 - val_loss: 8.0068e-08
# Epoch 46/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.5467e-08 - val_accuracy: 1.0000 - val_loss: 6.2642e-08
# Epoch 47/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 5.8872e-08 - val_accuracy: 1.0000 - val_loss: 4.8436e-08
# Epoch 48/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 4.5442e-08 - val_accuracy: 1.0000 - val_loss: 3.7283e-08
# Epoch 49/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 3.5080e-08 - val_accuracy: 1.0000 - val_loss: 3.0778e-08
# Epoch 50/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.9989e-08 - val_accuracy: 1.0000 - val_loss: 2.7897e-08
# Epoch 51/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.7333e-08 - val_accuracy: 1.0000 - val_loss: 2.5797e-08
# Epoch 52/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.5372e-08 - val_accuracy: 1.0000 - val_loss: 2.4218e-08
# Epoch 53/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.3893e-08 - val_accuracy: 1.0000 - val_loss: 2.2998e-08
# Epoch 54/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.8155 - loss: 3.0570 - val_accuracy: 1.0000 - val_loss: 7.3372e-08
# Epoch 55/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.3620e-08 - val_accuracy: 1.0000 - val_loss: 7.3320e-08
# Epoch 56/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.3522e-08 - val_accuracy: 1.0000 - val_loss: 7.3243e-08
# Epoch 57/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.3514e-08 - val_accuracy: 1.0000 - val_loss: 7.3214e-08
# Epoch 58/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.3393e-08 - val_accuracy: 1.0000 - val_loss: 7.3118e-08
# Epoch 59/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.3262e-08 - val_accuracy: 1.0000 - val_loss: 7.3104e-08
# Epoch 60/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.3321e-08 - val_accuracy: 1.0000 - val_loss: 7.3071e-08
# Epoch 61/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.3176e-08 - val_accuracy: 1.0000 - val_loss: 7.3032e-08
# Epoch 62/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.3136e-08 - val_accuracy: 1.0000 - val_loss: 7.2994e-08
# Epoch 63/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.3163e-08 - val_accuracy: 1.0000 - val_loss: 7.2827e-08
# Epoch 1/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 13s 14ms/step - accuracy: 0.2239 - loss: 0.7151 - val_accuracy: 0.5124 - val_loss: 0.6918
# Epoch 2/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.4795 - loss: 0.6914 - val_accuracy: 0.5167 - val_loss: 0.6867
# Epoch 3/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.8320 - loss: 0.4229 - val_accuracy: 1.0000 - val_loss: 0.0568
# Epoch 4/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0479 - val_accuracy: 1.0000 - val_loss: 0.0298
# Epoch 5/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0264 - val_accuracy: 1.0000 - val_loss: 0.0183
# Epoch 6/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 7/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 8/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 9/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 10/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 11/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 12/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 13/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 8.2841e-04
# Epoch 14/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.5749e-04 - val_accuracy: 1.0000 - val_loss: 5.7211e-04
# Epoch 15/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 5.2322e-04 - val_accuracy: 1.0000 - val_loss: 3.9534e-04
# Epoch 16/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 3.6159e-04 - val_accuracy: 1.0000 - val_loss: 2.7327e-04
# Epoch 17/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.4994e-04 - val_accuracy: 1.0000 - val_loss: 1.8893e-04
# Epoch 18/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.7283e-04 - val_accuracy: 1.0000 - val_loss: 1.3068e-04
# Epoch 19/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.1954e-04 - val_accuracy: 1.0000 - val_loss: 9.0383e-05
# Epoch 20/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 8.2679e-05 - val_accuracy: 1.0000 - val_loss: 6.2508e-05
# Epoch 21/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 5.7178e-05 - val_accuracy: 1.0000 - val_loss: 4.3226e-05
# Epoch 22/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 3.9541e-05 - val_accuracy: 1.0000 - val_loss: 2.9898e-05
# Epoch 23/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.7353e-05 - val_accuracy: 1.0000 - val_loss: 2.0688e-05
# Epoch 24/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.8928e-05 - val_accuracy: 1.0000 - val_loss: 1.4316e-05
# Epoch 25/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.3097e-05 - val_accuracy: 1.0000 - val_loss: 9.9055e-06
# Epoch 26/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 9.0881e-06 - val_accuracy: 1.0000 - val_loss: 6.9537e-06
# Epoch 27/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 6.3514e-06 - val_accuracy: 1.0000 - val_loss: 4.7862e-06
# Epoch 28/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 4.3766e-06 - val_accuracy: 1.0000 - val_loss: 3.3077e-06
# Epoch 29/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 3.0266e-06 - val_accuracy: 1.0000 - val_loss: 2.2917e-06
# Epoch 30/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 1.0000 - loss: 2.0981e-06 - val_accuracy: 1.0000 - val_loss: 1.5913e-06
# Epoch 31/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.4576e-06 - val_accuracy: 1.0000 - val_loss: 1.1076e-06
# Epoch 32/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.0152e-06 - val_accuracy: 1.0000 - val_loss: 7.7343e-07
# Epoch 33/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 7.0947e-07 - val_accuracy: 1.0000 - val_loss: 5.4228e-07
# Epoch 34/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 4.9802e-07 - val_accuracy: 1.0000 - val_loss: 3.8208e-07
# Epoch 35/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.5362e-05 - val_accuracy: 1.0000 - val_loss: 2.9745e-07
# Epoch 36/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.9746e-07 - val_accuracy: 1.0000 - val_loss: 2.9724e-07
# Epoch 37/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.9719e-07 - val_accuracy: 1.0000 - val_loss: 2.9677e-07
# Epoch 38/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.9671e-07 - val_accuracy: 1.0000 - val_loss: 2.9609e-07
# Epoch 39/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.9588e-07 - val_accuracy: 1.0000 - val_loss: 2.9501e-07
# Epoch 40/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.9461e-07 - val_accuracy: 1.0000 - val_loss: 2.9334e-07
# Epoch 41/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.9276e-07 - val_accuracy: 1.0000 - val_loss: 2.9078e-07
# Epoch 42/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.8991e-07 - val_accuracy: 1.0000 - val_loss: 2.8687e-07
# Epoch 43/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.8572e-07 - val_accuracy: 1.0000 - val_loss: 2.8150e-07
# Epoch 44/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.7977e-07 - val_accuracy: 1.0000 - val_loss: 2.7347e-07
# Epoch 45/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.7085e-07 - val_accuracy: 1.0000 - val_loss: 2.6174e-07
# Epoch 46/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.5798e-07 - val_accuracy: 1.0000 - val_loss: 2.4515e-07
# Epoch 47/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.3996e-07 - val_accuracy: 1.0000 - val_loss: 2.2274e-07
# Epoch 48/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.1674e-07 - val_accuracy: 1.0000 - val_loss: 1.9755e-07
# Epoch 49/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.9036e-07 - val_accuracy: 1.0000 - val_loss: 1.6770e-07
# Epoch 50/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6001e-07 - val_accuracy: 1.0000 - val_loss: 1.3879e-07
# Epoch 51/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.3181e-07 - val_accuracy: 1.0000 - val_loss: 1.1104e-07
# Epoch 52/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.0442e-07 - val_accuracy: 1.0000 - val_loss: 8.7429e-08
# Epoch 53/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 8.2975e-08 - val_accuracy: 1.0000 - val_loss: 7.0154e-08
# Epoch 54/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 6.6241e-08 - val_accuracy: 1.0000 - val_loss: 5.5228e-08
# Epoch 55/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 5.1979e-08 - val_accuracy: 1.0000 - val_loss: 4.2995e-08
# Epoch 56/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 4.0410e-08 - val_accuracy: 1.0000 - val_loss: 3.3362e-08
# Epoch 57/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 3.2119e-08 - val_accuracy: 1.0000 - val_loss: 2.9753e-08
# Epoch 58/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.9098e-08 - val_accuracy: 1.0000 - val_loss: 2.7294e-08
# Epoch 59/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.6782e-08 - val_accuracy: 1.0000 - val_loss: 2.5370e-08
# Epoch 60/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.4978e-08 - val_accuracy: 1.0000 - val_loss: 2.3869e-08
# Epoch 61/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.3555e-08 - val_accuracy: 1.0000 - val_loss: 2.2691e-08
# Epoch 62/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.2432e-08 - val_accuracy: 1.0000 - val_loss: 2.1754e-08
# Epoch 63/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 1.0000 - loss: 2.1544e-08 - val_accuracy: 1.0000 - val_loss: 2.0996e-08
# Epoch 64/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.0832e-08 - val_accuracy: 1.0000 - val_loss: 2.0374e-08
# Epoch 65/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 2.0241e-08 - val_accuracy: 1.0000 - val_loss: 1.9853e-08
# Epoch 66/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.9730e-08 - val_accuracy: 1.0000 - val_loss: 1.9411e-08
# Epoch 67/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.9326e-08 - val_accuracy: 1.0000 - val_loss: 1.9031e-08
# Epoch 68/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.8974e-08 - val_accuracy: 1.0000 - val_loss: 1.8703e-08
# Epoch 69/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.8660e-08 - val_accuracy: 1.0000 - val_loss: 1.8418e-08
# Epoch 70/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.8382e-08 - val_accuracy: 1.0000 - val_loss: 1.8168e-08
# Epoch 71/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.8162e-08 - val_accuracy: 1.0000 - val_loss: 1.7949e-08
# Epoch 72/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.7953e-08 - val_accuracy: 1.0000 - val_loss: 1.7757e-08
# Epoch 73/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.7783e-08 - val_accuracy: 1.0000 - val_loss: 1.7589e-08
# Epoch 74/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.7627e-08 - val_accuracy: 1.0000 - val_loss: 1.7435e-08
# Epoch 75/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.7466e-08 - val_accuracy: 1.0000 - val_loss: 1.7264e-08
# Epoch 76/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.7285e-08 - val_accuracy: 1.0000 - val_loss: 1.7092e-08
# Epoch 77/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.7124e-08 - val_accuracy: 1.0000 - val_loss: 1.6976e-08
# Epoch 78/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.7020e-08 - val_accuracy: 1.0000 - val_loss: 1.6857e-08
# Epoch 79/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6913e-08 - val_accuracy: 1.0000 - val_loss: 1.6750e-08
# Epoch 80/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6794e-08 - val_accuracy: 1.0000 - val_loss: 1.6658e-08
# Epoch 81/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6705e-08 - val_accuracy: 1.0000 - val_loss: 1.6578e-08
# Epoch 82/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6611e-08 - val_accuracy: 1.0000 - val_loss: 1.6482e-08
# Epoch 83/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 5.0615e-05 - val_accuracy: 1.0000 - val_loss: 1.6655e-08
# Epoch 84/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6754e-08 - val_accuracy: 1.0000 - val_loss: 1.6655e-08
# Epoch 85/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6756e-08 - val_accuracy: 1.0000 - val_loss: 1.6655e-08
# Epoch 86/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6726e-08 - val_accuracy: 1.0000 - val_loss: 1.6655e-08
# Epoch 87/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6714e-08 - val_accuracy: 1.0000 - val_loss: 1.6655e-08
# Epoch 88/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6702e-08 - val_accuracy: 1.0000 - val_loss: 1.6655e-08
# Epoch 89/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6685e-08 - val_accuracy: 1.0000 - val_loss: 1.6656e-08
# Epoch 90/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6702e-08 - val_accuracy: 1.0000 - val_loss: 1.6653e-08
# Epoch 91/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6692e-08 - val_accuracy: 1.0000 - val_loss: 1.6626e-08
# Epoch 92/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 1.6683e-08 - val_accuracy: 1.0000 - val_loss: 1.6600e-08
# Epoch 1/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 13s 14ms/step - accuracy: 0.9567 - loss: 0.4998 - val_accuracy: 1.0000 - val_loss: 0.2085
# Epoch 2/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.1760 - val_accuracy: 1.0000 - val_loss: 0.1083
# Epoch 3/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0950 - val_accuracy: 1.0000 - val_loss: 0.0640
# Epoch 4/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0571 - val_accuracy: 0.9999 - val_loss: 0.0405
# Epoch 5/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0363 - val_accuracy: 1.0000 - val_loss: 0.0263
# Epoch 6/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9999 - loss: 0.0240 - val_accuracy: 1.0000 - val_loss: 0.0178
# Epoch 7/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0162 - val_accuracy: 1.0000 - val_loss: 0.0120
# Epoch 8/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 9/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 10/200
# 888/888 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 11/200
# 601/888 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 1.0000 - loss: 0.0036

# %%
best_model_stats
